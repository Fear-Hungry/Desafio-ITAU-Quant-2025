# %% [markdown]
# # Research Scripts Playbook
#
# Notebook que consolida a execução dos principais scripts de pesquisa utilizados no projeto. Cada célula shell reproduz o comando documentado no `README.md`, preservando os artefatos correspondentes em `results/`.

# %% [markdown]
# ## Preparação
#
# As células abaixo assumem que você está rodando a partir da raiz do repositório, com o ambiente Poetry já ativado. Caso preferir, substitua `poetry run` pelos binários do seu ambiente virtual.

# %%
# %%bash
# poetry install

# %% [markdown]
# ## 1. Walk-forward Baselines
#
# Gera métricas comparativas para 1/N, Risk Parity, MV shrink, HRP e 60/40.

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_baselines_comparison.py

# %% [markdown]
# ## 2. Mean-CVaR Tail Experiments

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_cvar_tail_experiment.py

# %% [markdown]
# ## 3. Meta-heurística (GA) para $\lambda$, $\eta$, $\tau$

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_ga_mv_walkforward.py

# %% [markdown]
# ## 4. Tracking Error e Hit-Rate

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_tracking_error_hit_rate.py

# %% [markdown]
# ## 5. Bootstrap de Sharpe (IC 95%)

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_bootstrap_ci.py

# %% [markdown]
# ## 6. Sensibilidade a Custos/Turnover

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_cost_sensitivity.py

# %% [markdown]
# ## 7. Detecção de Regimes e Stress Tests

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_regime_stress.py

# %% [markdown]
# ## 8. Sensibilidade à Janela de Estimação

# %%
# %%bash
# PYTHONPATH=src poetry run python scripts/research/run_window_sensitivity.py

# %% [markdown]
# ## 9. Próximos Passos
#
# - Consolide os artefatos gerados em `results/` para anexar ao relatório.
# - Registre as versões das dependências (`poetry show --tree`) se for compartilhar o notebook.
# - Opcional: converter os outputs em tabelas Markdown com `pandas` para comparação direta.
